# %% [markdown]
# ## IMPORT PYTHON

# %%
# !pip install nb_black
# %load_ext lab_black

# %%
import pandas as pd

# %% [markdown]
# ### Read the Data

# %%
df = pd.read_json("../../data/elections/counties_election_results_2020.json")

# %% [markdown]
# ### Just the first five rows

# %%
df.head()
# Out:
#   state_name  county_fips county_name  votes_gop  votes_dem  total_votes  \
# 0    Alabama         1001     Autauga      19838       7503        27770
# 1    Alabama         1003     Baldwin      83544      24578       109679
# 2    Alabama         1005     Barbour       5622       4816        10518
# 3    Alabama         1007        Bibb       7525       1986         9595
# 4    Alabama         1009      Blount      24711       2640        27588
#
#    margin_dem  margin_gop  pct_dem  pct_gop  dem_diff  gop_diff winner
# 0      -12335       12335       27       71       -44        44    gop
# 1      -58966       58966       22       76       -54        54    gop
# 2        -806         806       46       53        -7         7    gop
# 3       -5539        5539       21       78       -57        57    gop
# 4      -22071       22071       10       90       -80        80    gop

# %% [markdown]
# ### Election Results for Alabama

# %%
df[df["state_name"] == "Alabama"]
# Out:
#    state_name  county_fips county_name  votes_gop  votes_dem  total_votes  \
# 0     Alabama         1001     Autauga      19838       7503        27770
# 1     Alabama         1003     Baldwin      83544      24578       109679
# 2     Alabama         1005     Barbour       5622       4816        10518
# 3     Alabama         1007        Bibb       7525       1986         9595
# 4     Alabama         1009      Blount      24711       2640        27588
# ..        ...          ...         ...        ...        ...          ...
# 62    Alabama         1125  Tuscaloosa      51117      37765        90172
# 63    Alabama         1127      Walker      26002       4834        31170
# 64    Alabama         1129  Washington       6564       2258         8876
# 65    Alabama         1131      Wilcox       1833       4048         5903
# 66    Alabama         1133     Winston      10195        974        11284
#
#     margin_dem  margin_gop  pct_dem  pct_gop  dem_diff  gop_diff winner
# ...

# %% [markdown]
# ### Election Results for Washington

# %%
df[df["state_name"] == "Washington"]
# Out:
#       state_name  county_fips   county_name  votes_gop  votes_dem  \
# 2963  Washington        53001         Adams       3907       1814
# 2964  Washington        53003        Asotin       7319       4250
# 2965  Washington        53005        Benton      60365      38706
# 2966  Washington        53007        Chelan      22746      19349
# 2967  Washington        53009       Clallam      23062      24721
# 2968  Washington        53011         Clark     126303     140324
# 2969  Washington        53013      Columbia       1754        668
# 2970  Washington        53015       Cowlitz      34424      23938
# 2971  Washington        53017       Douglas      12955       7811
# 2972  Washington        53019         Ferry       2771       1486
# 2973  Washington        53021      Franklin      18039      13340
# 2974  Washington        53023      Garfield       1069        366
# 2975  Washington        53025         Grant      24764      11819
# ...

# %% [markdown]
# ### Election Results for Oregon

# %%
df[df["state_name"] == "Oregon"]
# Out:
#      state_name  county_fips county_name  votes_gop  votes_dem  total_votes  \
# 2218     Oregon        41001       Baker       7352       2346         9932
# 2219     Oregon        41003      Benton      14878      35827        52799
# 2220     Oregon        41005   Clackamas     110509     139043       257679
# 2221     Oregon        41007     Clatsop      10218      12916        23910
# 2222     Oregon        41009    Columbia      17150      13835        32221
# 2223     Oregon        41011        Coos      21829      14243        37075
# 2224     Oregon        41013       Crook      11287       3801        15448
# 2225     Oregon        41015       Curry       8484       6058        14925
# 2226     Oregon        41017   Deschutes      55646      65962       125234
# 2227     Oregon        41019     Douglas      43298      19160        64349
# 2228     Oregon        41021     Gilliam        834        324         1178
# ...

# %%
df[(df["state_name"] == "California") & (df["total_votes"] > 500000)].head()
# Out:
#      state_name  county_fips   county_name  votes_gop  votes_dem  total_votes  \
# 197  California         6001       Alameda     136309     617659       769864
# 203  California         6013  Contra Costa     152877     416386       581230
# 215  California         6037   Los Angeles    1145530    3028885      4263443
# 226  California         6059        Orange     676498     814009      1521725
# 229  California         6065     Riverside     448702     527945       996156
#
#      margin_dem  margin_gop  pct_dem  pct_gop  dem_diff  gop_diff winner
# 197      481350     -481350       80       18        62       -62    dem
# 203      263509     -263509       72       26        46       -46    dem
# 215     1883355    -1883355       71       27        44       -44    dem
# 226      137511     -137511       53       44         9        -9    dem
# 229       79243      -79243       53       45         8        -8    dem
