# %%
import pandas as pd

# %%
import geopandas as gpd

# %%
bike = gpd.read_file("data/Bike_Racks_RepairStation_Corrals.csv")

# %%
bike.head ()
# Out:
#                    X                 Y OBJECTID Side ARC_Zone  \
# 0  -118.203828083459  34.1210790315862        1    L
# 1  -118.205182017103  34.1395560864937        2    R
# 2  -118.330433383813  34.0049075783407        3    R
# 3  -118.276993050255  34.0903716441113        4    R    90026
# 4  -118.446197004595  34.0618467996777        5    L
#
#                                                 NAME                   TYPE  \
# 0                                     The Hermosillo                    Bar
# 1                                            Organix      Health Food Store
# 2                                       KAOS Network             MEDIA ARTS
# 3  Pine & Crane Noodle Co/ SK Restaurant Concepts...             Restaurant
# 4           Westwood Village Improvement Association  retail and restaurant
#
#                                       ADDRESS     CD  \
# 0       5125 York Blvd\nLos Angeles, CA 90042  CD 14
# 1  1731 Colorado Blvd. Los Angeles, CA. 90041  CD 14
# ...

# %%
bike.tail ()
# Out:
#                    X                 Y OBJECTID Side ARC_Zone  \
# 4  -118.446197004595  34.0618467996777        5    L
# 5  -118.323858175609  34.0747151712227        6    L
# 6  -118.176575751299  34.0871702306569        7    L
# 7  -118.247962799068  34.0470381244454        8    L    90013
# 8  -118.418113015471  34.2685099440758        9    L
#
#                                        NAME                   TYPE  \
# 4  Westwood Village Improvement Association  retail and restaurant
# 5          Larchmont Village Wine + Spirits          Sandwich Shop
# 6                     CD 14 - Barrio Action             Non Profit
# 7                        Peddler's Creamery         Ice Cream Shop
# 8                         Pacoima Beautiful             Non Profit
#
#                            ADDRESS     CD  \
# 4  1036 Broxton Ave., LA, CA 90024  CD 5
# 5                 215 N. Larchmont   CD 4
# 6           4927 E. Huntington Dr.  CD 14
# 7   458 S Main St, Los Angeles, CA   CD14
# ...

# %%
len (bike)
# Out:
# 9
